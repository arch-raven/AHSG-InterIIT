# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/india-headlines-news-dataset/india-news-headlines.csv

# %%
df = pd.read_csv("/kaggle/input/india-headlines-news-dataset/india-news-headlines.csv")

# %%
df.columns
# Out:
# Index(['publish_date', 'headline_category', 'headline_text'], dtype='object')

# %%
df.loc[:,"headline_category"].value_counts().sort_values(ascending=False)
# Out:
# india                                      288541
# unknown                                    209582
# city.mumbai                                134428
# city.delhi                                 127717
# business.india-business                    116761
#                                             ...
# business.faqs.gst-faqs                          8
# sports.cricket.sri-lanka-in-new-zealand         8
# sports.tennis.top-stories.tennis-atp            8
# scorecard-and-statistics                        8
# brandwire.technology.internet-apps              8
# Name: headline_category, Length: 1013, dtype: int64

# %%
for s in hc:
    if ("tech" in s) or ("mobile" in s):
        print(s)
# Out:
# tech.tech-news
# tech.it-services
# tech.jobs
# tech.how-to
# tech.computing
# tech
# tech.gaming
# tech.social
# sports.racing.tech-tonic
# tech.apps
# tech.reviews
# tech.pcs
# tech.mobiles
# tech.more-gadgets
# tech-news-news-wire
# brandwire.technology.internet-apps
# best-products.mobile-phones

# %%
d = df.loc[:,"headline_category"].value_counts()

# %%
d.loc[["tech.mobiles", "best-products.mobile-phones", "tech.more-gadgets"]]
# Out:
# tech.mobiles                   682
# best-products.mobile-phones     17
# tech.more-gadgets              310
# Name: headline_category, dtype: int64

# %%
df.loc[df['headline_category'] == "best-products.mobile-phones","headline_text"][:10].to_list()
# Out:
# ['Samsung Galaxy Note 9 price; specs; top features and how to buy',
#  'Upcoming smartphones: Best upcoming mobiles of 2018 in India',
#  'Best Smartphones to buy under Rs 20;000',
#  'Best OnePlus Mobiles of 2017 and 2018 in India',
#  'New smartphones in October 2018:OnePlus 6T;Google Pixel 3 XL',
#  'Upcoming mobile phones of November 2018 in India',
#  'oneplus 6t india launch today know the price specifications offers pre booking info',
#  'google confirms the launch of its foldable smartphone',
#  'Compare Redmi Note 5 Pro vs Redmi Note 6 Pro: What should you buy?',
#  'Best smartphones in India launched in 2018']

# %%
df.loc[df['headline_category'] == "tech.mobiles","headline_text"][:10].to_list()
# Out:
# ['6 best camera smartphones by budget',
#  "Meet HTC First; the 'Facebook phone'",
#  'HTC One review: The best Android phone yet?',
#  'HTC One launched in India at Rs 42;990',
#  'Nokia Lumia 520: 5 hot rivals',
#  'Gionee Dream D1 smartphone review',
#  '8 hot recent smartphone launches',
#  'Google Nexus 7 review: The best value-for-money tablet',
#  'Dell XPS 12 review: A remarkable; expensive affair',
#  'Nokia launches Lumia 720 at Rs 18;999']
